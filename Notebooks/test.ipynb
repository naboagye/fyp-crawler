# %%
import requests
import pandas as pd

url = 'https://covid19.who.int/WHO-COVID-19-global-table-data.csv'

#r = requests.get(url)
df = pd.read_csv(url)

df = df.filter(['Name', 'Cases - newly reported in last 7 days per 100000 population', 'Cases - newly reported in last 24 hours'])
df.head()
# Out:
#                        Name  \
# 0                    Global
# 1  United States of America
# 2                     India
# 3                    Brazil
# 4        Russian Federation
#
#    Cases - newly reported in last 7 days per 100000 population  \
# 0                                          34.077173
# 1                                         175.920000
# 2                                           5.690000
# 3                                         149.740000
# 4                                          72.950000
#
#    Cases - newly reported in last 24 hours
# 0                                   316173
# 1                                     7689
# 2                                    12194
# 3                                    51546
# 4                                    14861

# %%
import requests
import pandas as pd

url = 'https://covid19.who.int/WHO-COVID-19-global-table-data.csv'

#r = requests.get(url)
df = pd.read_csv(url)

df = df.filter(['Name', 'Cases - newly reported in last 7 days per 100000 population', 'Cases - newly reported in last 24 hours'])
df.head(10)
# Out:
#                        Name  \
# 0                    Global
# 1  United States of America
# 2                     India
# 3                    Brazil
# 4        Russian Federation
# 5        The United Kingdom
# 6                    France
# 7                     Spain
# 8                     Italy
# 9                    Turkey
#
#    Cases - newly reported in last 7 days per 100000 population  \
# 0                                          34.077173
# 1                                         175.920000
# 2                                           5.690000
# 3                                         149.740000
# 4                                          72.950000
# 5                                         150.580000
# 6                                         195.720000
# 7                                         148.350000
# 8                                         141.640000
# 9                                          65.570000
#
#    Cases - newly reported in last 24 hours
# 0                                   316173
# 1                                     7689
# 2                                    12194
# 3                                    51546
# 4                                    14861
# 5                                    15144
# 6                                    20279
# 7                                        0
# 8                                    13893
# 9                                     7763

# %%
import requests
import pandas as pd

url = 'https://covid19.who.int/WHO-COVID-19-global-table-data.csv'

#r = requests.get(url)
df = pd.read_csv(url)

df = df.filter(['Name', 'Cases - newly reported in last 7 days per 100000 population', 'Cases - newly reported in last 24 hours'])
df.Name
# Out:
# 0                        Global
# 1      United States of America
# 2                         India
# 3                        Brazil
# 4            Russian Federation
#                  ...
# 233                Saint Helena
# 234                     Tokelau
# 235                       Tonga
# 236                Turkmenistan
# 237                      Tuvalu
# Name: Name, Length: 238, dtype: object

# %%
df.head()
# Out:
#                        Name  \
# 0                    Global
# 1  United States of America
# 2                     India
# 3                    Brazil
# 4        Russian Federation
#
#    Cases - newly reported in last 7 days per 100000 population  \
# 0                                          34.077173
# 1                                         175.920000
# 2                                           5.690000
# 3                                         149.740000
# 4                                          72.950000
#
#    Cases - newly reported in last 24 hours
# 0                                   316173
# 1                                     7689
# 2                                    12194
# 3                                    51546
# 4                                    14861

# %%
df.France
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-9697ab670fb0> in <module>
# ----> 1 df.France
#
# ~/.pyenv/versions/3.9.0/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5460             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5461                 return self[name]
# -> 5462             return object.__getattribute__(self, name)
#    5463
#    5464     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'France'

# %%
df['France']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.pyenv/versions/3.9.0/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'France'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-e372fe76ad50> in <module>
# ----> 1 df['France']
#
# ~/.pyenv/versions/3.9.0/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~/.pyenv/versions/3.9.0/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'France'

# %%
df.loc[df['Name']=='France']
# Out:
#      Name  Cases - newly reported in last 7 days per 100000 population  \
# 6  France                                             195.72
#
#    Cases - newly reported in last 24 hours
# 6                                    20279

# %%
df
# Out:
#                          Name  \
# 0                      Global
# 1    United States of America
# 2                       India
# 3                      Brazil
# 4          Russian Federation
# ..                        ...
# 233              Saint Helena
# 234                   Tokelau
# 235                     Tonga
# 236              Turkmenistan
# 237                    Tuvalu
#
#      Cases - newly reported in last 7 days per 100000 population  \
# 0                                            34.077173
# 1                                           175.920000
# 2                                             5.690000
# 3                                           149.740000
# 4                                            72.950000
# ..                                                 ...
# 233                                           0.000000
# 234                                           0.000000
# 235                                           0.000000
# 236                                           0.000000
# 237                                           0.000000
#
#      Cases - newly reported in last 24 hours
# 0                                     316173
# 1                                       7689
# 2                                      12194
# 3                                      51546
# 4                                      14861
# ..                                       ...
# 233                                        0
# 234                                        0
# 235                                        0
# 236                                        0
# 237                                        0
#
# [238 rows x 3 columns]

# %%
df.loc[df['Name']=='France'].values
# Out:
# array([['France', 195.72, 20279]], dtype=object)

# %%
arr = df.loc[df['Name']=='France'].values

# %%
arr
# Out:
# array([['France', 195.72, 20279]], dtype=object)

# %%
arr[0]
# Out:
# array(['France', 195.72, 20279], dtype=object)

# %%
df.loc[df['Name']=='France'].values[0]
# Out:
# array(['France', 195.72, 20279], dtype=object)

# %%
df.loc[df['Name']=='France', 'Cases - newly reported in last 7 days per 100000 population'].values[0]
# Out:
# 195.72

# %%
df.loc[df['Name']=='France', 'Cases - newly reported in last 7 days per 100000 population'].values
# Out:
# array([195.72])

# %%
df.loc[df['Name']=='France', 'Cases - newly reported in last 24 hours'].values[0]
# Out:
# 20279

# %%
url = "https://en.wikipedia.org/wiki/COVID-19_lockdowns"
df = pd.read_html(url, match='COVID-19 pandemic lockdowns')
df = df[0]

# Removing unneccesary table headers
df.columns = df.columns.get_level_values(2)    

# Including only national lockdowns in dataframe
df = df.loc[df['Level'] == "National"]

# Removing brackets with hyperlinks from dates
df = df.replace(r"\[.*?\]","",regex=True)
df = df.replace(r"\(.*?\)","",regex=True)

# Replacing empty spaces or NaN with 0
df = df.fillna(0)

# Removing unneccesary columns
df.drop('Place', inplace=True, axis=1)
df.drop('Start date', inplace=True, axis=1)
df.drop('Length (days)', inplace=True, axis=1)
df.drop('Level', inplace=True, axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c4582740d011> in <module>
#       1 url = "https://en.wikipedia.org/wiki/COVID-19_lockdowns"
# ----> 2 df = pd.read_html(url, match='COVID-19 pandemic lockdowns')
#       3 df = df[0]
#       4
#       5 # Removing unneccesary table headers
#
# NameError: name 'pd' is not defined

# %%
import sys
import pandas as pd
import requests
from bs4 import BeautifulSoup
from datetime import datetime as dt, date, timedelta

# %%
# Getting correct table
url = "https://en.wikipedia.org/wiki/COVID-19_lockdowns"
df = pd.read_html(url, match='COVID-19 pandemic lockdowns')
df = df[0]

# Removing unneccesary table headers
df.columns = df.columns.get_level_values(2)    

# Including only national lockdowns in dataframe
df = df.loc[df['Level'] == "National"]

# Removing brackets with hyperlinks from dates
df = df.replace(r"\[.*?\]","",regex=True)
df = df.replace(r"\(.*?\)","",regex=True)

# Replacing empty spaces or NaN with 0
df = df.fillna(0)

# Removing unneccesary columns
df.drop('Place', inplace=True, axis=1)
df.drop('Start date', inplace=True, axis=1)
df.drop('Length (days)', inplace=True, axis=1)
df.drop('Level', inplace=True, axis=1)

# %%
df
# Out:
#     Country / territory    End date    End date    End date
# 0               Albania  2020-06-01           0           0
# 4             Argentina  2020-05-10           0           0
# 5               Armenia  2020-05-04           0           0
# 14            Australia  2020-05-15           0           0
# 15              Austria  2020-04-13  2020-11-30  2021-02-07
# ..                  ...         ...         ...         ...
# 144      United Kingdom  2020-07-04  2020-12-02  2021-03-29
# 145      United Kingdom  2020-06-29  2021-04-02           0
# 179           Venezuela  2020-05-13           0           0
# 180             Vietnam  2020-04-22           0           0
# 184            Zimbabwe  2020-05-02           0           0
#
# [82 rows x 4 columns]

# %%
df.columns = ['Country', 'L1', 'L2', 'L3']

# %%
df
# Out:
#             Country          L1          L2          L3
# 0           Albania  2020-06-01           0           0
# 4         Argentina  2020-05-10           0           0
# 5           Armenia  2020-05-04           0           0
# 14        Australia  2020-05-15           0           0
# 15          Austria  2020-04-13  2020-11-30  2021-02-07
# ..              ...         ...         ...         ...
# 144  United Kingdom  2020-07-04  2020-12-02  2021-03-29
# 145  United Kingdom  2020-06-29  2021-04-02           0
# 179       Venezuela  2020-05-13           0           0
# 180         Vietnam  2020-04-22           0           0
# 184        Zimbabwe  2020-05-02           0           0
#
# [82 rows x 4 columns]

# %%
result = []
for index, row in df.iterrows():
    if row['L2'] == 0:
        result.append(row['L1'])
    elif row['L3'] == 0:
        result.append(row['L2'])
    else:
        result.append(row['L3'])
        
df['Lockdown End'] = result

# %%
df
# Out:
#             Country          L1          L2          L3 Lockdown End
# 0           Albania  2020-06-01           0           0   2020-06-01
# 4         Argentina  2020-05-10           0           0   2020-05-10
# 5           Armenia  2020-05-04           0           0   2020-05-04
# 14        Australia  2020-05-15           0           0   2020-05-15
# 15          Austria  2020-04-13  2020-11-30  2021-02-07   2021-02-07
# ..              ...         ...         ...         ...          ...
# 144  United Kingdom  2020-07-04  2020-12-02  2021-03-29   2021-03-29
# 145  United Kingdom  2020-06-29  2021-04-02           0   2021-04-02
# 179       Venezuela  2020-05-13           0           0   2020-05-13
# 180         Vietnam  2020-04-22           0           0   2020-04-22
# 184        Zimbabwe  2020-05-02           0           0   2020-05-02
#
# [82 rows x 5 columns]

# %%
df.drop('L1', inplace=True, axis=1)
df.drop('L2', inplace=True, axis=1)
df.drop('L3', inplace=True, axis=1)

# %%
df
# Out:
#             Country Lockdown End
# 0           Albania   2020-06-01
# 4         Argentina   2020-05-10
# 5           Armenia   2020-05-04
# 14        Australia   2020-05-15
# 15          Austria   2021-02-07
# ..              ...          ...
# 144  United Kingdom   2021-03-29
# 145  United Kingdom   2021-04-02
# 179       Venezuela   2020-05-13
# 180         Vietnam   2020-04-22
# 184        Zimbabwe   2020-05-02
#
# [82 rows x 2 columns]

# %%
df.head(40)
# Out:
#            Country              Lockdown End
# 0          Albania                2020-06-01
# 4        Argentina                2020-05-10
# 5          Armenia                2020-05-04
# 14       Australia                2020-05-15
# 15         Austria                2021-02-07
# 16      Azerbaijan                2020-08-30
# 17      Bangladesh                2021-04-13
# 18        Barbados                2020-05-03
# 19         Belgium                2021-04-24
# 20         Bermuda                2020-05-02
# 21          Bhutan                2020-09-01
# 22         Bolivia                2020-07-31
# 23        Botswana                2020-04-30
# 26        Bulgaria                2021-03-31
# 32        Colombia                2020-06-30
# 33           Congo                2020-04-20
# 34      Costa Rica                2020-05-01
# 35         Croatia                2020-12-29
# 36          Cyprus                2021-01-31
# 37  Czech Republic                2021-03-28
# 38         Denmark                2021-03-01
# 39         Ecuador                2020-03-31
# 40     El Salvador                2020-04-02
# 41         Eritrea                2020-04-23
# 42         Estonia                2021-04-11
# 45          France                2021-05-03
# 47         Finland                2021-03-28
# 48         Georgia                2020-04-21
# 49         Germany  2021-03-01 to 2021-04-19
# 53          Greece                2021-03-22
# 56        Guernsey                2021-02-22
# 57        Honduras                2020-05-17
# 58         Hungary                2020-04-10
# 59           India                2020-06-07
# 60            Iran                2020-04-20
# 61            Iraq                2020-04-11
# 62         Ireland                2021-04-12
# 67          Israel                2021-02-07
# 68           Italy                2021-04-30
# 76          Jordan                2020-11-15

# %%
df.tail(40)
# Out:
#                   Country             Lockdown End
# 79                Lebanon               2020-11-28
# 80                  Libya               2020-06-27
# 81              Lithuania               2020-11-28
# 84               Malaysia               2021-02-10
# 85                 Mexico               2020-06-01
# 93               Mongolia               2020-12-01
# 95                Morocco               2020-06-10
# 96                Namibia               2020-05-04
# 97                  Nepal               2020-07-21
# 99            Netherlands               2021-03-02
# 100           New Zealand               2020-05-14
# 105       Northern Cyprus               2020-05-04
# 109              Pakistan               2020-05-09
# 110                Panama               2020-05-31
# 111      Papua New Guinea               2020-04-07
# 112              Paraguay               2020-05-03
# 113                  Peru               2020-06-30
# 118                Poland               2021-04-18
# 119              Portugal               2021-02-15
# 121               Romania               2020-05-12
# 123                Russia               2020-04-30
# 124                Rwanda               2020-04-19
# 125                 Samoa               2020-04-08
# 126            San Marino               2020-05-05
# 132                Serbia  2020-04-21to 2020-05-04
# 133             Singapore               2020-06-01
# 134          South Africa               2020-04-30
# 135                 Spain               2020-05-09
# 136             Sri Lanka               2020-06-21
# 137           Switzerland               2020-04-27
# 138              Thailand               2020-05-31
# 139   Trinidad and Tobago               2020-03-31
# 140               Tunisia               2020-04-19
# 142               Ukraine               2020-04-24
# 143  United Arab Emirates               2020-04-17
# 144        United Kingdom               2021-03-29
# 145        United Kingdom               2021-04-02
# 179             Venezuela               2020-05-13
# 180               Vietnam               2020-04-22
# 184              Zimbabwe               2020-05-02

# %%
df['Lockdown End'] = df['Lockdown End'].replace((df['Lockdown End']), (df['Lockdown End'])[:-6])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-b4022f9e5fbd> in <module>
# ----> 1 df['Lockdown End'] = df['Lockdown End'].replace((df['Lockdown End']), (df['Lockdown End'])[:-6])
#
# ~/.pyenv/versions/3.9.0/lib/python3.9/site-packages/pandas/core/series.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    4504         method="pad",
#    4505     ):
# -> 4506         return super().replace(
#    4507             to_replace=to_replace,
#    4508             value=value,
#
# ~/.pyenv/versions/3.9.0/lib/python3.9/site-packages/pandas/core/generic.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    6860                         if col in value.keys() and col in self
#    6861                     }
# -> 6862                     return self._replace_columnwise(mapping, inplace, regex)
#    6863
#    6864                 # {'A': NA} -> 0
#
# ~/.pyenv/versions/3.9.0/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5460             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5461                 return self[name]
# -> 5462             return object.__getattribute__(self, name)
#    5463
#    5464     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute '_replace_columnwise'

# %%
def format(x):
    if len(x) > 10:
        return(x[-10:])
    else:
        return(x)

# %%
df['Lockdown End'] = df['Lockdown End'].apply(format)

# %%
df.head(40)
# Out:
#            Country Lockdown End
# 0          Albania   2020-06-01
# 4        Argentina   2020-05-10
# 5          Armenia   2020-05-04
# 14       Australia   2020-05-15
# 15         Austria   2021-02-07
# 16      Azerbaijan   2020-08-30
# 17      Bangladesh   2021-04-13
# 18        Barbados   2020-05-03
# 19         Belgium   2021-04-24
# 20         Bermuda   2020-05-02
# 21          Bhutan   2020-09-01
# 22         Bolivia   2020-07-31
# 23        Botswana   2020-04-30
# 26        Bulgaria   2021-03-31
# 32        Colombia   2020-06-30
# 33           Congo   2020-04-20
# 34      Costa Rica   2020-05-01
# 35         Croatia   2020-12-29
# 36          Cyprus   2021-01-31
# 37  Czech Republic   2021-03-28
# 38         Denmark   2021-03-01
# 39         Ecuador   2020-03-31
# 40     El Salvador   2020-04-02
# 41         Eritrea   2020-04-23
# 42         Estonia   2021-04-11
# 45          France   2021-05-03
# 47         Finland   2021-03-28
# 48         Georgia   2020-04-21
# 49         Germany   2021-04-19
# 53          Greece   2021-03-22
# 56        Guernsey   2021-02-22
# 57        Honduras   2020-05-17
# 58         Hungary   2020-04-10
# 59           India   2020-06-07
# 60            Iran   2020-04-20
# 61            Iraq   2020-04-11
# 62         Ireland   2021-04-12
# 67          Israel   2021-02-07
# 68           Italy   2021-04-30
# 76          Jordan   2020-11-15

# %%
df.tail(40)
# Out:
#                   Country Lockdown End
# 79                Lebanon   2020-11-28
# 80                  Libya   2020-06-27
# 81              Lithuania   2020-11-28
# 84               Malaysia   2021-02-10
# 85                 Mexico   2020-06-01
# 93               Mongolia   2020-12-01
# 95                Morocco   2020-06-10
# 96                Namibia   2020-05-04
# 97                  Nepal   2020-07-21
# 99            Netherlands   2021-03-02
# 100           New Zealand   2020-05-14
# 105       Northern Cyprus   2020-05-04
# 109              Pakistan   2020-05-09
# 110                Panama   2020-05-31
# 111      Papua New Guinea   2020-04-07
# 112              Paraguay   2020-05-03
# 113                  Peru   2020-06-30
# 118                Poland   2021-04-18
# 119              Portugal   2021-02-15
# 121               Romania   2020-05-12
# 123                Russia   2020-04-30
# 124                Rwanda   2020-04-19
# 125                 Samoa   2020-04-08
# 126            San Marino   2020-05-05
# 132                Serbia   2020-05-04
# 133             Singapore   2020-06-01
# 134          South Africa   2020-04-30
# 135                 Spain   2020-05-09
# 136             Sri Lanka   2020-06-21
# 137           Switzerland   2020-04-27
# 138              Thailand   2020-05-31
# 139   Trinidad and Tobago   2020-03-31
# 140               Tunisia   2020-04-19
# 142               Ukraine   2020-04-24
# 143  United Arab Emirates   2020-04-17
# 144        United Kingdom   2021-03-29
# 145        United Kingdom   2021-04-02
# 179             Venezuela   2020-05-13
# 180               Vietnam   2020-04-22
# 184              Zimbabwe   2020-05-02

# %%
df.tail(2)
# Out:
#       Country Lockdown End
# 180   Vietnam   2020-04-22
# 184  Zimbabwe   2020-05-02

# %%
df.tail(42)
# Out:
#                   Country Lockdown End
# 77                 Kosovo   020-05-04
# 78                 Kuwait   2020-05-31
# 79                Lebanon   2020-11-28
# 80                  Libya   2020-06-27
# 81              Lithuania   2020-11-28
# 84               Malaysia   2021-02-10
# 85                 Mexico   2020-06-01
# 93               Mongolia   2020-12-01
# 95                Morocco   2020-06-10
# 96                Namibia   2020-05-04
# 97                  Nepal   2020-07-21
# 99            Netherlands   2021-03-02
# 100           New Zealand   2020-05-14
# 105       Northern Cyprus   2020-05-04
# 109              Pakistan   2020-05-09
# 110                Panama   2020-05-31
# 111      Papua New Guinea   2020-04-07
# 112              Paraguay   2020-05-03
# 113                  Peru   2020-06-30
# 118                Poland   2021-04-18
# 119              Portugal   2021-02-15
# 121               Romania   2020-05-12
# 123                Russia   2020-04-30
# 124                Rwanda   2020-04-19
# 125                 Samoa   2020-04-08
# 126            San Marino   2020-05-05
# 132                Serbia   2020-05-04
# 133             Singapore   2020-06-01
# 134          South Africa   2020-04-30
# 135                 Spain   2020-05-09
# 136             Sri Lanka   2020-06-21
# 137           Switzerland   2020-04-27
# 138              Thailand   2020-05-31
# 139   Trinidad and Tobago   2020-03-31
# 140               Tunisia   2020-04-19
# 142               Ukraine   2020-04-24
# 143  United Arab Emirates   2020-04-17
# 144        United Kingdom   2021-03-29
# 145        United Kingdom   2021-04-02
# 179             Venezuela   2020-05-13
# 180               Vietnam   2020-04-22
# 184              Zimbabwe   2020-05-02

# %%
df.drop( df[ df['Lockdown End'] == 0 ].index , inplace=True)

# %%
df
# Out:
#             Country Lockdown End
# 0           Albania   2020-06-01
# 4         Argentina   2020-05-10
# 5           Armenia   2020-05-04
# 14        Australia   2020-05-15
# 15          Austria   2021-02-07
# ..              ...          ...
# 144  United Kingdom   2021-03-29
# 145  United Kingdom   2021-04-02
# 179       Venezuela   2020-05-13
# 180         Vietnam   2020-04-22
# 184        Zimbabwe   2020-05-02
#
# [82 rows x 2 columns]

# %%
df['Current Lockdown?'] = df['Lockdown End'].apply(test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-14664bf486ff> in <module>
# ----> 1 df['Current Lockdown?'] = df['Lockdown End'].apply(test)
#
# NameError: name 'test' is not defined

# %%
def test(x):
    today = date.today()
    start = today - timedelta(days=today.weekday())
    start = dt.combine(start, dt.min.time())
    print(start)
    test_date = dt.strptime(x.strip(), "%Y-%m-%d")
    return test_date >= start

# %%
df['Current Lockdown?'] = df['Lockdown End'].apply(test)
# Out:
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-14664bf486ff> in <module>
# ----> 1 df['Current Lockdown?'] = df['Lockdown End'].apply(test)
#
# ~/.pyenv/versions/3.9.0/lib/python3.9/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4133             else:
#    4134                 values = self.astype(object)._values
# -> 4135                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4136
#    4137         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-23-d51f18311293> in test(x)
#       4     start = dt.combine(start, dt.min.time())
#       5     print(start)
# ----> 6     test_date = dt.strptime(x.strip(), "%Y-%m-%d")
#       7     return test_date >= start
#
# ~/.pyenv/versions/3.9.0/lib/python3.9/_strptime.py in _strptime_datetime(cls, data_string, format)
#     566     """Return a class cls instance based on the input string and the
#     567     format string."""
# --> 568     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#     569     tzname, gmtoff = tt[-2:]
#     570     args = tt[:6] + (fraction,)
#
# ~/.pyenv/versions/3.9.0/lib/python3.9/_strptime.py in _strptime(data_string, format)
#     347     found = format_regex.match(data_string)
#     348     if not found:
# --> 349         raise ValueError("time data %r does not match format %r" %
#     350                          (data_string, format))
#     351     if len(data_string) != found.end():
#
# ValueError: time data '020-05-04' does not match format '%Y-%m-%d'

# %%
df['Lockdown End'] = pd.to_datetime(df['Lockdown End'], format='%Y-%m-%d', errors='coerce')

# %%
df
# Out:
#             Country Lockdown End
# 0           Albania   2020-06-01
# 4         Argentina   2020-05-10
# 5           Armenia   2020-05-04
# 14        Australia   2020-05-15
# 15          Austria   2021-02-07
# ..              ...          ...
# 144  United Kingdom   2021-03-29
# 145  United Kingdom   2021-04-02
# 179       Venezuela   2020-05-13
# 180         Vietnam   2020-04-22
# 184        Zimbabwe   2020-05-02
#
# [82 rows x 2 columns]

# %%
df.head(42)
# Out:
#            Country Lockdown End
# 0          Albania   2020-06-01
# 4        Argentina   2020-05-10
# 5          Armenia   2020-05-04
# 14       Australia   2020-05-15
# 15         Austria   2021-02-07
# 16      Azerbaijan   2020-08-30
# 17      Bangladesh   2021-04-13
# 18        Barbados   2020-05-03
# 19         Belgium   2021-04-24
# 20         Bermuda   2020-05-02
# 21          Bhutan   2020-09-01
# 22         Bolivia   2020-07-31
# 23        Botswana   2020-04-30
# 26        Bulgaria   2021-03-31
# 32        Colombia   2020-06-30
# 33           Congo   2020-04-20
# 34      Costa Rica   2020-05-01
# 35         Croatia   2020-12-29
# 36          Cyprus   2021-01-31
# 37  Czech Republic   2021-03-28
# 38         Denmark   2021-03-01
# 39         Ecuador   2020-03-31
# 40     El Salvador   2020-04-02
# 41         Eritrea   2020-04-23
# 42         Estonia   2021-04-11
# 45          France   2021-05-03
# 47         Finland   2021-03-28
# 48         Georgia   2020-04-21
# 49         Germany   2021-04-19
# 53          Greece   2021-03-22
# 56        Guernsey   2021-02-22
# 57        Honduras   2020-05-17
# 58         Hungary   2020-04-10
# 59           India   2020-06-07
# 60            Iran   2020-04-20
# 61            Iraq   2020-04-11
# 62         Ireland   2021-04-12
# 67          Israel   2021-02-07
# 68           Italy   2021-04-30
# 76          Jordan   2020-11-15
# 77          Kosovo          NaT
# 78          Kuwait   2020-05-31

# %%
df.dropna()
# Out:
#             Country Lockdown End
# 0           Albania   2020-06-01
# 4         Argentina   2020-05-10
# 5           Armenia   2020-05-04
# 14        Australia   2020-05-15
# 15          Austria   2021-02-07
# ..              ...          ...
# 144  United Kingdom   2021-03-29
# 145  United Kingdom   2021-04-02
# 179       Venezuela   2020-05-13
# 180         Vietnam   2020-04-22
# 184        Zimbabwe   2020-05-02
#
# [81 rows x 2 columns]

# %%
df['Current Lockdown?'] = df['Lockdown End'].apply(test)
# Out:
# 2021-04-12 00:00:00
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-14664bf486ff> in <module>
# ----> 1 df['Current Lockdown?'] = df['Lockdown End'].apply(test)
#
# ~/.pyenv/versions/3.9.0/lib/python3.9/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4133             else:
#    4134                 values = self.astype(object)._values
# -> 4135                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4136
#    4137         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-23-d51f18311293> in test(x)
#       4     start = dt.combine(start, dt.min.time())
#       5     print(start)
# ----> 6     test_date = dt.strptime(x.strip(), "%Y-%m-%d")
#       7     return test_date >= start
#
# AttributeError: 'Timestamp' object has no attribute 'strip'

# %%
def test(x):
    today = date.today()
    start = today - timedelta(days=today.weekday())
    start = dt.combine(start, dt.min.time())
    #test_date = dt.strptime(x.strip(), "%Y-%m-%d")
    return x >= start

# %%
df['Current Lockdown?'] = df['Lockdown End'].apply(test)
# Out:
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00
# 2021-04-12 00:00:00

# %%
df
# Out:
#             Country Lockdown End  Current Lockdown?
# 0           Albania   2020-06-01              False
# 4         Argentina   2020-05-10              False
# 5           Armenia   2020-05-04              False
# 14        Australia   2020-05-15              False
# 15          Austria   2021-02-07              False
# ..              ...          ...                ...
# 144  United Kingdom   2021-03-29              False
# 145  United Kingdom   2021-04-02              False
# 179       Venezuela   2020-05-13              False
# 180         Vietnam   2020-04-22              False
# 184        Zimbabwe   2020-05-02              False
#
# [82 rows x 3 columns]

# %%
df = df.loc[df['Current Lockdown?'] == True]

# %%
df
# Out:
#         Country Lockdown End  Current Lockdown?
# 17   Bangladesh   2021-04-13               True
# 19      Belgium   2021-04-24               True
# 45       France   2021-05-03               True
# 49      Germany   2021-04-19               True
# 62      Ireland   2021-04-12               True
# 68        Italy   2021-04-30               True
# 118      Poland   2021-04-18               True

# %%
# Getting correct table
url = "https://en.wikipedia.org/wiki/COVID-19_lockdowns"
df = pd.read_html(url, match='COVID-19 pandemic lockdowns')
df = df[0]

# Removing unneccesary table headers
df.columns = df.columns.get_level_values(2)    

# Including only national lockdowns in dataframe
df = df.loc[df['Level'] == "National"]

# Removing brackets with hyperlinks from dates
df = df.replace(r"\[.*?\]","",regex=True)
df = df.replace(r"\(.*?\)","",regex=True)

# Replacing empty spaces or NaN with 0
df = df.fillna(0)

# Removing unneccesary columns
df.drop('Place', inplace=True, axis=1)
df.drop('Start date', inplace=True, axis=1)
df.drop('Length (days)', inplace=True, axis=1)
df.drop('Level', inplace=True, axis=1)

# %%
df
# Out:
#     Country / territory    End date    End date    End date
# 0               Albania  2020-06-01           0           0
# 4             Argentina  2020-05-10           0           0
# 5               Armenia  2020-05-04           0           0
# 14            Australia  2020-05-15           0           0
# 15              Austria  2020-04-13  2020-11-30  2021-02-07
# ..                  ...         ...         ...         ...
# 144      United Kingdom  2020-07-04  2020-12-02  2021-03-29
# 145      United Kingdom  2020-06-29  2021-04-02           0
# 179           Venezuela  2020-05-13           0           0
# 180             Vietnam  2020-04-22           0           0
# 184            Zimbabwe  2020-05-02           0           0
#
# [82 rows x 4 columns]

# %%
# Getting correct table
url = "https://en.wikipedia.org/wiki/COVID-19_lockdowns"
df = pd.read_html(url, match='COVID-19 pandemic lockdowns')

# %%
df
# Out:
# [                        vteCOVID-19 pandemic lockdowns  \
#                                     Country / territory
#                                     Country / territory
#  0                                              Albania
#  1                                              Algeria
#  2                                              Algeria
#  3                                            Argentina
#  4                                            Argentina
#  ..                                                 ...
#  181                                            Vietnam
#  182                                            Vietnam
#  183                                            Vietnam
#  184                                           Zimbabwe
#  185  Outbreak ongoing: Lockdown data as of 14 April...
#
#                                                          \
#                                                   Place
#                                                   Place
#  0                                              Albania
#  1                                              Algiers
#  2                                                Blida
#  3                                 Greater Buenos Aires
#  4                                  Rest of the country
#  ..                                                 ...
#  181                                            Da Nang
#  182                                           Chi Linh
#  183                                          Hai Duong
#  184                                           Zimbabwe
#  185  Outbreak ongoing: Lockdown data as of 14 April...
#
#                                                          \
#                                          First lockdown
#                                              Start date
#  0                                       2020-03-13[60]
#  1                                       2020-03-23[62]
#  2                                       2020-03-23[62]
#  3                                       2020-03-19[64]
#  4                                       2020-03-19[64]
#  ..                                                 ...
#  181                                                NaN
#  182                                                NaN
#  183                                                NaN
#  184                                    2020-03-30[383]
#  185  Outbreak ongoing: Lockdown data as of 14 April...
#
#                                                          \
#
#                                                End date
#  0                                       2020-06-01[61]
#  1                                       2020-05-14[63]
#  2                                       2020-05-14[63]
#  3                                       2020-11-08[65]
#  4                                       2020-05-10[66]
#  ..                                                 ...
#  181                                                NaN
#  182                                                NaN
#  183                                                NaN
#  184                                    2020-05-02[384]
#  185  Outbreak ongoing: Lockdown data as of 14 April...
#
#                                                          \
#
#                                           Length (days)
#  0                                                   80
#  1                                                   52
#  2                                                   52
#  3                                                  234
#  4                                                   52
#  ..                                                 ...
#  181                                                NaN
#  182                                                NaN
#  183                                                NaN
#  184                                                 33
#  185  Outbreak ongoing: Lockdown data as of 14 April...
#
#                                                          \
#                                         Second lockdown
#                                              Start date
#  0                                                  NaN
#  1                                                  NaN
#  2                                                  NaN
#  3                                                  NaN
#  4                                                  NaN
#  ..                                                 ...
#  181                                    2020-07-28[379]
#  182                                    2021-01-28[381]
#  183                                    2021-02-16[382]
#  184                                                NaN
#  185  Outbreak ongoing: Lockdown data as of 14 April...
#
#                                                          \
#
#                                                End date
#  0                                                  NaN
#  1                                                  NaN
#  2                                                  NaN
#  3                                                  NaN
#  4                                                  NaN
#  ..                                                 ...
#  181                                    2020-09-05[380]
#  182                                         2021-03-02
#  183                                         2021-03-02
#  184                                                NaN
#  185  Outbreak ongoing: Lockdown data as of 14 April...
#
#                                                          \
#
#                                           Length (days)
#  0                                                  NaN
#  1                                                  NaN
#  2                                                  NaN
#  3                                                  NaN
#  4                                                  NaN
#  ..                                                 ...
#  181                                                 39
#  182                                                 33
#  183                                                 14
#  184                                                NaN
#  185  Outbreak ongoing: Lockdown data as of 14 April...
#
#                                                          \
#                                          Third lockdown
#                                              Start date
#  0                                                  NaN
#  1                                                  NaN
#  2                                                  NaN
#  3                                                  NaN
#  4                                                  NaN
#  ..                                                 ...
#  181                                                NaN
#  182                                                NaN
#  183                                                NaN
#  184                                                NaN
#  185  Outbreak ongoing: Lockdown data as of 14 April...
#
#                                                          \
#
#                                                End date
#  0                                                  NaN
#  1                                                  NaN
#  2                                                  NaN
#  3                                                  NaN
#  4                                                  NaN
#  ..                                                 ...
#  181                                                NaN
#  182                                                NaN
#  183                                                NaN
#  184                                                NaN
#  185  Outbreak ongoing: Lockdown data as of 14 April...
#
#                                                          \
#
#                                           Length (days)
#  0                                                  NaN
#  1                                                  NaN
#  2                                                  NaN
#  3                                                  NaN
#  4                                                  NaN
#  ..                                                 ...
#  181                                                NaN
#  182                                                NaN
#  183                                                NaN
#  184                                                NaN
#  185  Outbreak ongoing: Lockdown data as of 14 April...
#
#
#                                     Unnamed: 11_level_1
#                                                   Level
#  0                                             National
#  1                                                 City
#  2                                                 City
#  3                                    Metropolitan Area
#  4                                             National
#  ..                                                 ...
#  181                                               City
#  182                                               City
#  183                                           Province
#  184                                           National
#  185  Outbreak ongoing: Lockdown data as of 14 April...
#
#  [186 rows x 12 columns]]

# %%
df
# Out:
#     Country / territory    End date    End date    End date
# 0               Albania  2020-06-01           0           0
# 4             Argentina  2020-05-10           0           0
# 5               Armenia  2020-05-04           0           0
# 14            Australia  2020-05-15           0           0
# 15              Austria  2020-04-13  2020-11-30  2021-02-07
# ..                  ...         ...         ...         ...
# 144      United Kingdom  2020-07-04  2020-12-02  2021-03-29
# 145      United Kingdom  2020-06-29  2021-04-02           0
# 179           Venezuela  2020-05-13           0           0
# 180             Vietnam  2020-04-22           0           0
# 184            Zimbabwe  2020-05-02           0           0
#
# [82 rows x 4 columns]

# %%
# Renaming columns
df.columns = ['Country', 'L1', 'L2', 'L3']

# Determining the column with the end date of the latest lockdown
result = []
for index, row in df.iterrows():
    if row['L2'] == 0:
        result.append(row['L1'])
    elif row['L3'] == 0:
        result.append(row['L2'])
    else:
        result.append(row['L3'])
        
df['Lockdown End'] = result

# Dropping byproduct attributes in determining end date of lockdowns
df.drop('L1', inplace=True, axis=1)
df.drop('L2', inplace=True, axis=1)
df.drop('L3', inplace=True, axis=1)

# Removing dates that are ranges and replacing not "set dates" with zero values
df['Lockdown End'] = df['Lockdown End'].apply(format)

# Dropping any rows that don't have an end date in the format YYYY-MM-DD
df['Lockdown End'] = pd.to_datetime(df['Lockdown End'], format='%Y-%m-%d', errors='coerce')
df.dropna()

# Applying function to determine countries with a current lockdown
df['Current Lockdown?'] = df['Lockdown End'].apply(testDate)
df = df.loc[df['Current Lockdown?'] == True]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-3b824fa95c46> in <module>
#      27
#      28 # Applying function to determine countries with a current lockdown
# ---> 29 df['Current Lockdown?'] = df['Lockdown End'].apply(testDate)
#      30 df = df.loc[df['Current Lockdown?'] == True]
#
# NameError: name 'testDate' is not defined

# %%
def testDate(x):
    today = date.today()
    start = today - timedelta(days=today.weekday())
    start = dt.combine(start, dt.min.time())
    return x >= start

# function to replace any date values that are ranges with just the end date 
def format(x):
    if len(x) > 10:
        return(x[-10:])
    else:
        return(x)

# %%
# Renaming columns
df.columns = ['Country', 'L1', 'L2', 'L3']

# Determining the column with the end date of the latest lockdown
result = []
for index, row in df.iterrows():
    if row['L2'] == 0:
        result.append(row['L1'])
    elif row['L3'] == 0:
        result.append(row['L2'])
    else:
        result.append(row['L3'])
        
df['Lockdown End'] = result

# Dropping byproduct attributes in determining end date of lockdowns
df.drop('L1', inplace=True, axis=1)
df.drop('L2', inplace=True, axis=1)
df.drop('L3', inplace=True, axis=1)

# Removing dates that are ranges and replacing not "set dates" with zero values
df['Lockdown End'] = df['Lockdown End'].apply(format)

# Dropping any rows that don't have an end date in the format YYYY-MM-DD
df['Lockdown End'] = pd.to_datetime(df['Lockdown End'], format='%Y-%m-%d', errors='coerce')
df.dropna()

# Applying function to determine countries with a current lockdown
df['Current Lockdown?'] = df['Lockdown End'].apply(testDate)
df = df.loc[df['Current Lockdown?'] == True]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-3b824fa95c46> in <module>
#       1 # Renaming columns
# ----> 2 df.columns = ['Country', 'L1', 'L2', 'L3']
#       3
#       4 # Determining the column with the end date of the latest lockdown
#       5 result = []
#
# ~/.pyenv/versions/3.9.0/lib/python3.9/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5473         try:
#    5474             object.__getattribute__(self, name)
# -> 5475             return object.__setattr__(self, name, value)
#    5476         except AttributeError:
#    5477             pass
#
# pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~/.pyenv/versions/3.9.0/lib/python3.9/site-packages/pandas/core/generic.py in _set_axis(self, axis, labels)
#     667     def _set_axis(self, axis: int, labels: Index) -> None:
#     668         labels = ensure_index(labels)
# --> 669         self._mgr.set_axis(axis, labels)
#     670         self._clear_item_cache()
#     671
#
# ~/.pyenv/versions/3.9.0/lib/python3.9/site-packages/pandas/core/internals/managers.py in set_axis(self, axis, new_labels)
#     218
#     219         if new_len != old_len:
# --> 220             raise ValueError(
#     221                 f"Length mismatch: Expected axis has {old_len} elements, new "
#     222                 f"values have {new_len} elements"
#
# ValueError: Length mismatch: Expected axis has 2 elements, new values have 4 elements

# %%
df
# Out:
#             Country Lockdown End
# 0           Albania   2020-06-01
# 4         Argentina   2020-05-10
# 5           Armenia   2020-05-04
# 14        Australia   2020-05-15
# 15          Austria   2021-02-07
# ..              ...          ...
# 144  United Kingdom   2021-03-29
# 145  United Kingdom   2021-04-02
# 179       Venezuela   2020-05-13
# 180         Vietnam   2020-04-22
# 184        Zimbabwe   2020-05-02
#
# [82 rows x 2 columns]

# %%
# Applying function to determine countries with a current lockdown
df['Current Lockdown?'] = df['Lockdown End'].apply(testDate)
df = df.loc[df['Current Lockdown?'] == True]

# %%
df
# Out:
#         Country Lockdown End  Current Lockdown?
# 17   Bangladesh   2021-04-13               True
# 19      Belgium   2021-04-24               True
# 45       France   2021-05-03               True
# 49      Germany   2021-04-19               True
# 62      Ireland   2021-04-12               True
# 68        Italy   2021-04-30               True
# 118      Poland   2021-04-18               True
